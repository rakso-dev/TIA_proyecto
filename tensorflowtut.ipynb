# %% [markdown]
# <a href="https://colab.research.google.com/github/rakso-dev/TIA_proyecto/blob/main/tensorflowtut.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import numpy as np
import matplotlib.pyplot as plt

# %%
a = [1, 0, 0, 1]
b = [1, 1, 0, 0]
c = [0, 0, 1, 1]

categorias = [[1, 0, 0], [0, 1, 0], [0, 0 , 1]]

# %%
model = Sequential()

model.add(Dense(4, input_dim=4, activation="relu"))
model.add(Dense(3, activation="softmax"))

model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])

# %%
X_train = np.array([a, b , c])
ytrain = np.array(categorias)

# %%
X_train.shape
ytrain.shape
# Out:
# (3, 3)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 4)                 20
#
#  dense_1 (Dense)             (None, 3)                 15
#
# ...
# Total params: 35
# Trainable params: 35
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(x=X_train, y=ytrain, epochs=500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6064 - accuracy: 0.6667
# Epoch 2/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.6059 - accuracy: 0.6667
# Epoch 3/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6054 - accuracy: 0.6667
# Epoch 4/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6049 - accuracy: 0.6667
# Epoch 5/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6044 - accuracy: 0.6667
# Epoch 6/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6039 - accuracy: 0.6667
# Epoch 7/500
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6034 - accuracy: 0.6667
# Epoch 8/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6029 - accuracy: 0.6667
# Epoch 9/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.6024 - accuracy: 0.6667
# Epoch 10/500
# ...

# %%
plt.plot(history.history['accuracy'])

# %%
plt.plot(history.history['loss'])

# %%
model.predict([[1, 1 , 0, 0]])
# Out:
# 1/1 [==============================] - 0s 92ms/step
# array([[0.14676498, 0.85152435, 0.0017107 ]], dtype=float32)

# %%
model.predict([[1, 0, 0, 1]])
# Out:
# 1/1 [==============================] - 0s 35ms/step
# array([[0.7487321 , 0.1882479 , 0.06301994]], dtype=float32)

# %%
model.predict([[0, 0, 1, 1]])
# Out:
# 1/1 [==============================] - 0s 33ms/step
# array([[0.15155575, 0.06134862, 0.78709567]], dtype=float32)

# %%
model.predict([[0, 0, 0, 1]])
# Out:
# 1/1 [==============================] - 0s 33ms/step
# array([[0.46715584, 0.1496065 , 0.38323763]], dtype=float32)
